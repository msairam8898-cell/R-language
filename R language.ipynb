# %%
a<-5
print(a)
# Out:
# [1] 5

# %%
a<-2
b<-3
print(a+b)
# Out:
# [1] 5

# %%
a<-2
b<-3
print(a*b)
# Out:
# [1] 6

# %%
a<-c(1,2,3,4)
b<-c(5,6,7,8)
print(a+b)
# Out:
# [1]  6  8 10 12

# %%
a<-c(1,2,3,4)
print(a[1])
# Out:
# [1] 1

# %%
marks<-c(34,5,7,8)
max(marks)
# Out:
# [1] 34

# %%
student_data<-data.frame(
  ID=c(12,34,566,45),
  name=c("sai","krishna","ram","rahul"),
  Age=c(19,20,23,12)
)
print(student_data)
# Out:
#    ID    name Age
# 1  12     sai  19
# 2  34 krishna  20
# 3 566     ram  23
# 4  45   rahul  12

# %%
x<-10.5
print(x)
class(x)
# Out:
# [1] 10.5
# [1] "numeric"

# %%
x<-9L
print(x)
class(x)
# Out:
# [1] 9
# [1] "integer"

# %%
x<-"sai"
print(x)
class(x)
# Out:
# [1] "sai"
# [1] "character"

# %%
arr<-array(1:6,dim=c(2,3))
print(arr)
# Out:
#      [,1] [,2] [,3]
# [1,]    1    3    5
# [2,]    2    4    6

# %%
arr<-array(1:12,dim=c(2,3,2))
print(arr)
# Out:
# , , 1
#
#      [,1] [,2] [,3]
# [1,]    1    3    5
# [2,]    2    4    6
#
# , , 2
#
#      [,1] [,2] [,3]
# [1,]    7    9   11
# [2,]    8   10   12

# %%
arr<-array(
  1:2,
  dim=c(3,2,2),
  dimnames=list(
    c("r1","r2","r3"),
    c("c1","c2"),
    c("m1","m2")
  )
)
arr
dim(arr)
length(arr)
# Out:
# , , m1
#
#    c1 c2
# r1  1  2
# r2  2  1
# r3  1  2
#
# , , m2
#
#    c1 c2
# r1  1  2
# r2  2  1
# r3  1  2
# [1] 3 2 2
# [1] 12

# %%
x <- c(1, 2, 3, 4, 5)
y <- c(6, 7, 8, 9, 10)

plot(
  x, y,
  type = "o",
  main = "Simple Line Plot",
  xlab = "X Values",
  ylab = "Y Values"
)
# Out:
# Plot with title “Simple Line Plot”
